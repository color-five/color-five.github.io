# %%
a=1
b=2
c=a+b
print(c)
# Out:
# 3

# %%
print(f"c={c}")
# Out:
# c=3

# %%
name='lps'
print(f"Hello {name}")
# Out:
# Hello lps

# %%
my_list=["lps happy"]
print(my_list)
# Out:
# ['lps happy']

# %%
my_list.append(" handsome")

# %%
print(my_list)
# Out:
# ['lps happy', 'so handsome', ' handsome', ' handsome']

# %%
def my_add(a,b):
    return a+b
    
    print(my_add(1,3))

# %%
from add import my_add

# %%
def my_add(a,b):
    return a+b

# %%
print(my_add(1,3))
# Out:
# 4

# %%
from add import my_add
print(my_add(1,3))
# Out:
# 4
