# %%
# 从1到20中筛选出偶数，并计算其3次方
even_cubes = [num ** 3 for num in range(1, 21) if num % 2 == 0]
print(even_cubes)  # 输出: [8, 64, 216, 512, 1000, 1728, 2744, 4096, 5832, 8000]
# Out:
# [8, 64, 216, 512, 1000, 1728, 2744, 4096, 5832, 8000]
